# %%
import google.generativeai as genai
genai.configure(api_key="AIzaSyDL0jn5X5detxTh6--basmueLWMXAddDPA")

model = genai.GenerativeModel("gemini-2.5-flash-preview-04-17")

response = model.generate_content("Can you build summarisation table between ai vs gen ai vs agentic ai") 
print(response.text)

import pathlib
import textwrap

import google.generativeai as genai

from IPython.display import display
from IPython.display import Markdown

def to_markdown(text):
    text = text.replace('*',' *')
    return Markdown(textwrap.indent(text, '>', predicate=lambda _: True))
import pathlib
import textwrap

import google.generativeai as genai

from IPython.display import display
from IPython.display import Markdown

def to_markdown(text):
    text = text.replace('*',' *')
    return Markdown(textwrap.indent(text, '>', predicate=lambda _: True))


for m in genai.list_models():
    if 'generateContent' in m.supported_generation_methods:
        print(m.name)
model= genai.GenerativeModel('models/gemini-2.5-flash-preview-05-20')


import PIL.Image
img = PIL.Image.open(r'C:\Swapna\Learning\PYTHON\FS DataScience\GenAI\pic.jpg')
img

response = model.generate_content(img)
to_markdown(response.text)
# Out:
# Okay, here is a summarization table comparing AI, Generative AI (GenAI), and Agentic AI. They represent different levels of scope, capability, and autonomy within the field of artificial intelligence.
#
# | Feature / Concept | AI (Artificial Intelligence) | Generative AI (GenAI) | Agentic AI |
# |---|---|---|---|
# | **Scope** | **Broadest:** The entire field of making machines perform tasks that typically require human intelligence. | **Subset of AI:** Specifically focused on creating new content. | **Layered on AI (often GenAI):** Refers to systems that can act autonomously to achieve goals. |
# | **Primary Goal** | To mimic or achieve human-like cognitive functions (learning, problem-solving, perception, etc.). | To create novel and diverse outputs (text, images, code, audio, video, etc.). | To achieve a specific objective through independent planning, action, and interaction with an environment or tools. |
# | **Key Capability / Output** | Decision-making, learning, problem-solving, pattern recognition, classification, prediction. Can include *many* things. | Generating new content based on learned patterns from data. Outputs *content*. | Planning complex tasks, breaking them down, executing steps, using tools/APIs, interacting with external systems, self-correction. Outputs are *actions* leading to a *result*. |
# | **Autonomy / Agency** | Varies greatly, often low or limited to specific tasks. Not a defining characteristic. | Low. Typically reacts to a prompt to generate output. Does not plan or act autonomously beyond generation. | High. Designed to act independently, make decisions about steps, and execute sequences of actions without constant human input for each step. This is the *defining* characteristic. |
# | **Interaction** | Can be interactive or background. Depends on the specific AI application. | Primarily takes input (prompt) and provides output (generated content). Limited interaction with external environments/tools. | Actively interacts with external systems, databases, websites, APIs, software tools, and potentially the physical world to accomplish its goal. |
# | **Relationship** | The overarching field. | A specific *type* or *application* of AI focused on creation. | An *architecture* or *paradigm* often built *on top of* or *using* underlying AI capabilities (like GenAI for reasoning), focused on autonomous action. |
# | **Typical Examples** | Spam filters, recommendation systems, expert systems, image recognition, simple chatbots, robotic process automation (RPA). | ChatGPT, DALL-E, Midjourney, GitHub Copilot, text-to-speech models, Generative Adversarial Networks (GANs). | AI systems that can autonomously browse the web for research, plan and execute coding projects, manage complex workflows involving multiple tools, or act as advanced personal assistants coordinating tasks across applications. |
#
# **In Summary:**
#
# *   **AI** is the broad concept of intelligent machines.
# *   **Generative AI** is a *type* of AI focused specifically on *creating* things.
# *   **Agentic AI** is a *paradigm* or *architecture* within AI that emphasizes autonomous *action* and goal achievement, often *using* capabilities like GenAI for reasoning and planning.
# models/gemini-1.0-pro-vision-latest
# models/gemini-pro-vision
# models/gemini-1.5-pro-latest
# models/gemini-1.5-pro-002
# models/gemini-1.5-pro
# models/gemini-1.5-flash-latest
# models/gemini-1.5-flash
# models/gemini-1.5-flash-002
# models/gemini-1.5-flash-8b
# models/gemini-1.5-flash-8b-001
# models/gemini-1.5-flash-8b-latest
# models/gemini-2.5-pro-preview-03-25
# models/gemini-2.5-flash-preview-04-17
# models/gemini-2.5-flash-preview-05-20
# models/gemini-2.5-flash
# models/gemini-2.5-flash-preview-04-17-thinking
# models/gemini-2.5-flash-lite-preview-06-17
# models/gemini-2.5-pro-preview-05-06
# models/gemini-2.5-pro-preview-06-05
# models/gemini-2.5-pro
# models/gemini-2.0-flash-exp
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.0-flash-lite-preview-02-05
# models/gemini-2.0-flash-lite-preview
# models/gemini-2.0-pro-exp
# models/gemini-2.0-pro-exp-02-05
# models/gemini-exp-1206
# models/gemini-2.0-flash-thinking-exp-01-21
# models/gemini-2.0-flash-thinking-exp
# models/gemini-2.0-flash-thinking-exp-1219
# models/gemini-2.5-flash-preview-tts
# models/gemini-2.5-pro-preview-tts
# models/learnlm-2.0-flash-experimental
# models/gemma-3-1b-it
# models/gemma-3-4b-it
# models/gemma-3-12b-it
# models/gemma-3-27b-it
# models/gemma-3n-e4b-it
# models/gemma-3n-e2b-it
# >This striking aerial image captures two paragliders soaring high above a fascinating frozen landscape.
# >
# >The two paragliders are the central subjects, seen from directly above. The one on the left features a vibrant blue canopy with orange and light blue accents. The one on the right has a bright yellow canopy with orange and white details. Below each canopy, the silhouette of the pilot in their harness is faintly visible, suggesting they are relatively high above the surface.
# >
# >The background is a vast expanse of ice, likely a frozen lake or large body of water, displaying incredibly intricate and abstract patterns. These patterns resemble swirling marble, organic formations, and delicate ripples, primarily in shades of white, grey, and charcoal. There are distinct darker areas, possibly sections of open water or very thin ice, which contrast sharply with the lighter, textured ice. The patterns on the ice are highly varied, including wavy lines, concentric circles, and fractal-like designs, creating a unique and artistic natural tapestry.
# >
# >The overall perspective is from above, giving the viewer a unique bird's-eye view of both the colorful paragliders and the mesmerizing patterns on the ice below, creating a visually compelling scene that highlights the beauty of both human flight and natural formations.
